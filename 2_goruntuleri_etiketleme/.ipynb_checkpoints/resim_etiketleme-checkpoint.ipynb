# %%
import warnings
warnings.filterwarnings('ignore')

from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array

import numpy as np

from keras.applications.vgg16 import preprocess_input as VggPre
from keras.applications.vgg16 import decode_predictions as VggDec
# Out:
# Using TensorFlow backend.

# %%
from keras.applications.vgg16 import VGG16
VGGmodel = VGG16()

# %% [markdown]
# ## Resimlerin En Yuksek Olasılıga Sahip Etiketlerini Buluyoruz

# %%
def VggPred(image):
    image = img_to_array(image)
  # veriyi model icin boyutlandir
    image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
  # resmi Vgg icin hazirla
    image = VggPre(image)
  # tahminleri al
    yhat = VGGmodel.predict(image)
  # tahminleri etiketlere ve olasiliklara donustur
    label = VggDec(yhat)

    prediction_list = []
    prediction = label[0][0][1]
   
    for i in range(5):
        prediction = label[0][i][1]
        prediction_list.append(prediction)
    
    #for i in range(5):
        #prediction += str(i+1)+'. prediction: ' +str(label[0][i][1]) +' %'+ str(round(label[0][i][2]*100,3)) + '\n'
    return prediction_list

# %% [markdown]
# ## Imgs Klasorundeki Resimleri Tahmin Edilen Etiketlerle Ayni Isimdeki Klasorlere Yerlestiriyoruz

# %%
import os
if not os.path.exists('kategoriler'):
    os.makedirs('kategoriler')

# %% [markdown]
# Her Resmi Imgs'den alip, kategoriler klasorunun altindaki ilgili klasore kopyaliyoruz

# %%
from shutil import copy2
def kategorilendir(img, name):
    kategori = VggPred(img)
    directory = 'kategoriler/' + kategori + '/'
    if not os.path.exists(directory):
        os.makedirs(directory)
    copy2('Imgs/' + name, directory + name)

# %%
for counter in range(1,9103):
    try:
        name = str(counter) + '.jpg'
        img = load_img('Imgs/' + name, target_size=(224, 224))
        kategorilendir(img, name)
        
    except IOError:
        print('Error')

# %% [markdown]
# ## Etiketleme Islemi Bittikten Sonra Her Etiketteki Resim Sayisina Bakiyoruz

# %%
kategoriSayilari = {}

# %%
import os
for dirpath, dirnames, filenames in os.walk('kategoriler'):
    directory = dirpath.replace('kategoriler/','')
    kategoriSayilari[str(directory)] =  len(filenames)

# %%
kategoriSayilari
# Out:
# {'kategoriler': 1,
#  'parking_meter': 4,
#  'streetcar': 60,
#  'seashore': 5,
#  'Great_Pyrenees': 1,
#  'valley': 4,
#  'moped': 2,
#  'limousine': 1,
#  'apron': 5,
#  'microwave': 41,
#  'barbell': 3,
#  'safe': 3,
#  'chime': 8,
#  'coil': 8,
#  'golfcart': 10,
#  'paintbrush': 2,
#  'missile': 6,
#  'dogsled': 2,
#  'shield': 2,
#  'pool_table': 18,
#  'toaster': 4,
#  'sundial': 3,
#  'dial_telephone': 2,
#  'wardrobe': 226,
#  'gas_pump': 12,
#  'bedroom': 31,
#  'Boston_bull': 4,
#  'waffle_iron': 1,
#  'restaurant': 792,
#  'fountain': 71,
#  'velvet': 2,
#  'plunger': 1,
#  'wool': 2,
#  'tractor': 2,
#  'balloon': 1,
#  'canoe': 3,
#  'cradle': 21,
#  'radiator': 22,
#  'plate_rack': 2,
#  'bookshop': 39,
#  'bobsled': 1,
#  'steel_arch_bridge': 5,
#  'monitor': 1,
#  'window_shade': 97,
#  'spotlight': 2,
#  'trolleybus': 12,
#  'toucan': 2,
#  'horizontal_bar': 1,
#  'grocery_store': 13,
#  'gondola': 19,
#  'maypole': 3,
#  'wall_clock': 2,
#  'pirate': 3,
#  'gown': 5,
#  'scale': 1,
#  'apiary': 5,
#  'jigsaw_puzzle': 2,
#  'greenhouse': 57,
#  'rocking_chair': 23,
#  'desk': 25,
#  'shovel': 6,
#  'television': 2,
#  'hourglass': 6,
#  'cellular_telephone': 2,
#  'hoopskirt': 2,
#  'shoe_shop': 15,
#  'fire_screen': 6,
#  'grand_piano': 5,
#  'stupa': 21,
#  'bakery': 11,
#  'cinema': 396,
#  'fireboat': 4,
#  'harvester': 2,
#  'studio_couch': 439,
#  'jeep': 4,
#  'file': 3,
#  'binder': 4,
#  'parallel_bars': 2,
#  'organ': 23,
#  'triumphal_arch': 2,
#  'washer': 7,
#  'candle': 6,
#  'bathroom': 8,
#  "carpenter's_kit": 1,
#  'butcher_shop': 4,
#  'kimono': 1,
#  'harp': 5,
#  'shoji': 46,
#  'mailbox': 13,
#  'sarong': 2,
#  'table_lamp': 17,
#  'barrel': 5,
#  'crane': 17,
#  'book_jacket': 2,
#  'barrow': 2,
#  'toyshop': 2,
#  'hay': 1,
#  'clog': 1,
#  'street_sign': 10,
#  'passenger_car': 45,
#  'swab': 3,
#  'swing': 21,
#  'sewing_machine': 2,
#  'poncho': 1,
#  'church': 93,
#  'vestment': 17,
#  'forklift': 8,
#  'tobacco_shop': 23,
#  'jackfruit': 2,
#  'quilt': 97,
#  'chainlink_fence': 2,
#  'bath_towel': 3,
#  'upright': 6,
#  'others': 18,
#  'jinrikisha': 4,
#  'entertainment_center': 14,
#  'lampshade': 7,
#  'sandbar': 4,
#  'viaduct': 5,
#  'yawl': 2,
#  'library': 124,
#  'alp': 60,
#  'cliff': 2,
#  'loudspeaker': 2,
#  'rain_barrel': 14,
#  'carton': 13,
#  'fire_engine': 4,
#  'throne': 75,
#  'suspension_bridge': 20,
#  'china_cabinet': 81,
#  'carousel': 2,
#  'motor_scooter': 2,
#  'acoustic_guitar': 2,
#  'bubble': 1,
#  'bell_cote': 141,
#  'Christmas_stocking': 11,
#  'thatch': 60,
#  'four-poster': 1132,
#  'bookcase': 31,
#  'minibus': 13,
#  'cab': 35,
#  'birdhouse': 39,
#  'turnstile': 38,
#  'moving_van': 13,
#  'dome': 4,
#  'maze': 16,
#  'lakeside': 73,
#  'lumbermill': 11,
#  'stove': 4,
#  'garbage_truck': 18,
#  'snowplow': 13,
#  'pot': 9,
#  'confectionery': 21,
#  'picket_fence': 243,
#  'vending_machine': 8,
#  'mobile_home': 82,
#  'pay-phone': 7,
#  'amphibian': 1,
#  'trailer_truck': 2,
#  'barn': 25,
#  'traffic_light': 25,
#  'crate': 15,
#  'palace': 228,
#  'scoreboard': 10,
#  'parachute': 2,
#  'patio': 433,
#  'tile_roof': 13,
#  'hard_disc': 2,
#  'barbershop': 66,
#  'shower_curtain': 87,
#  'container_ship': 7,
#  'theater_curtain': 43,
#  'horse_cart': 5,
#  'croquet_ball': 1,
#  'cash_machine': 21,
#  'toilet_tissue': 10,
#  'megalith': 3,
#  'thresher': 3,
#  'hair_spray': 3,
#  'guillotine': 22,
#  'prison': 204,
#  'punching_bag': 4,
#  'umbrella': 15,
#  'boathouse': 184,
#  'switch': 4,
#  'planetarium': 6,
#  'toilet_seat': 35,
#  'ski': 7,
#  'marimba': 3,
#  'chest': 14,
#  'broom': 1,
#  'stone_wall': 2,
#  'flagpole': 31,
#  'seat_belt': 1,
#  'hand_blower': 1,
#  'stage': 4,
#  'sombrero': 2,
#  'dam': 11,
#  'bathtub': 14,
#  'school_bus': 5,
#  'solar_dish': 9,
#  'cuirass': 1,
#  'cannon': 2,
#  'recreational_vehicle': 2,
#  'wine_bottle': 6,
#  'castle': 46,
#  'obelisk': 18,
#  'slot': 4,
#  'backpack': 4,
#  'panpipe': 1,
#  'yurt': 26,
#  'water_tower': 14,
#  'bannister': 105,
#  'doormat': 5,
#  'window_screen': 1,
#  'barber_chair': 22,
#  'mountain_tent': 4,
#  'tub': 56,
#  'bullet_train': 1,
#  'ashcan': 3,
#  'purse': 2,
#  'refrigerator': 12,
#  'prayer_rug': 7,
#  'dining_table': 226,
#  'paper_towel': 13,
#  'mosque': 29,
#  'oscilloscope': 2,
#  'sliding_door': 235,
#  'gong': 4,
#  'airliner': 1,
#  'abacus': 3,
#  'paddlewheel': 35,
#  'hamper': 6,
#  'matchstick': 3,
#  'home_theater': 368,
#  'French_loaf': 2,
#  'pier': 4,
#  'safety_pin': 1,
#  'liner': 5,
#  'geyser': 2,
#  'pole': 3,
#  'medicine_chest': 126,
#  'oxcart': 2,
#  'tow_truck': 2,
#  'monastery': 138,
#  'dock': 3,
#  'washbasin': 176,
#  'mosquito_net': 24,
#  'orange': 2,
#  'vault': 35,
#  'worm_fence': 8,
#  'altar': 109,
#  'building': 15,
#  'crib': 35,
#  'beacon': 18,
#  'stretcher': 6,
#  'dumbbell': 6}

# %%
import operator
kategoriSayilari = sorted(kategoriSayilari.items(), key=operator.itemgetter(1),reverse=True)

# %%
kategoriSayilari
# Out:
# [('four-poster', 1132),
#  ('restaurant', 792),
#  ('studio_couch', 439),
#  ('patio', 433),
#  ('cinema', 396),
#  ('home_theater', 368),
#  ('picket_fence', 243),
#  ('sliding_door', 235),
#  ('palace', 228),
#  ('wardrobe', 226),
#  ('dining_table', 226),
#  ('prison', 204),
#  ('boathouse', 184),
#  ('washbasin', 176),
#  ('bell_cote', 141),
#  ('monastery', 138),
#  ('medicine_chest', 126),
#  ('library', 124),
#  ('altar', 109),
#  ('bannister', 105),
#  ('window_shade', 97),
#  ('quilt', 97),
#  ('church', 93),
#  ('shower_curtain', 87),
#  ('mobile_home', 82),
#  ('china_cabinet', 81),
#  ('throne', 75),
#  ('lakeside', 73),
#  ('fountain', 71),
#  ('barbershop', 66),
#  ('streetcar', 60),
#  ('alp', 60),
#  ('thatch', 60),
#  ('greenhouse', 57),
#  ('tub', 56),
#  ('shoji', 46),
#  ('castle', 46),
#  ('passenger_car', 45),
#  ('theater_curtain', 43),
#  ('microwave', 41),
#  ('bookshop', 39),
#  ('birdhouse', 39),
#  ('turnstile', 38),
#  ('cab', 35),
#  ('toilet_seat', 35),
#  ('paddlewheel', 35),
#  ('vault', 35),
#  ('crib', 35),
#  ('bedroom', 31),
#  ('bookcase', 31),
#  ('flagpole', 31),
#  ('mosque', 29),
#  ('yurt', 26),
#  ('desk', 25),
#  ('barn', 25),
#  ('traffic_light', 25),
#  ('mosquito_net', 24),
#  ('rocking_chair', 23),
#  ('organ', 23),
#  ('tobacco_shop', 23),
#  ('radiator', 22),
#  ('guillotine', 22),
#  ('barber_chair', 22),
#  ('cradle', 21),
#  ('stupa', 21),
#  ('swing', 21),
#  ('confectionery', 21),
#  ('cash_machine', 21),
#  ('suspension_bridge', 20),
#  ('gondola', 19),
#  ('pool_table', 18),
#  ('others', 18),
#  ('garbage_truck', 18),
#  ('obelisk', 18),
#  ('beacon', 18),
#  ('table_lamp', 17),
#  ('crane', 17),
#  ('vestment', 17),
#  ('maze', 16),
#  ('shoe_shop', 15),
#  ('crate', 15),
#  ('umbrella', 15),
#  ('building', 15),
#  ('entertainment_center', 14),
#  ('rain_barrel', 14),
#  ('chest', 14),
#  ('bathtub', 14),
#  ('water_tower', 14),
#  ('grocery_store', 13),
#  ('mailbox', 13),
#  ('carton', 13),
#  ('minibus', 13),
#  ('moving_van', 13),
#  ('snowplow', 13),
#  ('tile_roof', 13),
#  ('paper_towel', 13),
#  ('gas_pump', 12),
#  ('trolleybus', 12),
#  ('refrigerator', 12),
#  ('bakery', 11),
#  ('Christmas_stocking', 11),
#  ('lumbermill', 11),
#  ('dam', 11),
#  ('golfcart', 10),
#  ('street_sign', 10),
#  ('scoreboard', 10),
#  ('toilet_tissue', 10),
#  ('pot', 9),
#  ('solar_dish', 9),
#  ('chime', 8),
#  ('coil', 8),
#  ('bathroom', 8),
#  ('forklift', 8),
#  ('vending_machine', 8),
#  ('worm_fence', 8),
#  ('washer', 7),
#  ('lampshade', 7),
#  ('pay-phone', 7),
#  ('container_ship', 7),
#  ('ski', 7),
#  ('prayer_rug', 7),
#  ('missile', 6),
#  ('shovel', 6),
#  ('hourglass', 6),
#  ('fire_screen', 6),
#  ('candle', 6),
#  ('upright', 6),
#  ('planetarium', 6),
#  ('wine_bottle', 6),
#  ('hamper', 6),
#  ('stretcher', 6),
#  ('dumbbell', 6),
#  ('seashore', 5),
#  ('apron', 5),
#  ('steel_arch_bridge', 5),
#  ('gown', 5),
#  ('apiary', 5),
#  ('grand_piano', 5),
#  ('harp', 5),
#  ('barrel', 5),
#  ('viaduct', 5),
#  ('horse_cart', 5),
#  ('school_bus', 5),
#  ('doormat', 5),
#  ('liner', 5),
#  ('parking_meter', 4),
#  ('valley', 4),
#  ('toaster', 4),
#  ('Boston_bull', 4),
#  ('fireboat', 4),
#  ('jeep', 4),
#  ('binder', 4),
#  ('butcher_shop', 4),
#  ('jinrikisha', 4),
#  ('sandbar', 4),
#  ('fire_engine', 4),
#  ('dome', 4),
#  ('stove', 4),
#  ('punching_bag', 4),
#  ('switch', 4),
#  ('stage', 4),
#  ('slot', 4),
#  ('backpack', 4),
#  ('mountain_tent', 4),
#  ('gong', 4),
#  ('pier', 4),
#  ('barbell', 3),
#  ('safe', 3),
#  ('sundial', 3),
#  ('canoe', 3),
#  ('maypole', 3),
#  ('pirate', 3),
#  ('file', 3),
#  ('swab', 3),
#  ('bath_towel', 3),
#  ('megalith', 3),
#  ('thresher', 3),
#  ('hair_spray', 3),
#  ('marimba', 3),
#  ('ashcan', 3),
#  ('abacus', 3),
#  ('matchstick', 3),
#  ('pole', 3),
#  ('dock', 3),
#  ('moped', 2),
#  ('paintbrush', 2),
#  ('dogsled', 2),
#  ('shield', 2),
#  ('dial_telephone', 2),
#  ('velvet', 2),
#  ('wool', 2),
#  ('tractor', 2),
#  ('plate_rack', 2),
#  ('spotlight', 2),
#  ('toucan', 2),
#  ('wall_clock', 2),
#  ('jigsaw_puzzle', 2),
#  ('television', 2),
#  ('cellular_telephone', 2),
#  ('hoopskirt', 2),
#  ('harvester', 2),
#  ('parallel_bars', 2),
#  ('triumphal_arch', 2),
#  ('sarong', 2),
#  ('book_jacket', 2),
#  ('barrow', 2),
#  ('toyshop', 2),
#  ('sewing_machine', 2),
#  ('jackfruit', 2),
#  ('chainlink_fence', 2),
#  ('yawl', 2),
#  ('cliff', 2),
#  ('loudspeaker', 2),
#  ('carousel', 2),
#  ('motor_scooter', 2),
#  ('acoustic_guitar', 2),
#  ('trailer_truck', 2),
#  ('parachute', 2),
#  ('hard_disc', 2),
#  ('stone_wall', 2),
#  ('sombrero', 2),
#  ('cannon', 2),
#  ('recreational_vehicle', 2),
#  ('purse', 2),
#  ('oscilloscope', 2),
#  ('French_loaf', 2),
#  ('geyser', 2),
#  ('oxcart', 2),
#  ('tow_truck', 2),
#  ('orange', 2),
#  ('kategoriler', 1),
#  ('Great_Pyrenees', 1),
#  ('limousine', 1),
#  ('waffle_iron', 1),
#  ('plunger', 1),
#  ('balloon', 1),
#  ('bobsled', 1),
#  ('monitor', 1),
#  ('horizontal_bar', 1),
#  ('scale', 1),
#  ("carpenter's_kit", 1),
#  ('kimono', 1),
#  ('hay', 1),
#  ('clog', 1),
#  ('poncho', 1),
#  ('bubble', 1),
#  ('amphibian', 1),
#  ('croquet_ball', 1),
#  ('broom', 1),
#  ('seat_belt', 1),
#  ('hand_blower', 1),
#  ('cuirass', 1),
#  ('panpipe', 1),
#  ('window_screen', 1),
#  ('bullet_train', 1),
#  ('airliner', 1),
#  ('safety_pin', 1)]

# %% [markdown]
# ## En Cok Resmi Iceren Etiketleri Manuel Olarak Seciyoruz ve Spesifik Sınıflandırma Icin Kullaniyoruz

# %%
bathroom = ['washbasin', 'medicine_chest', 'tub', 'toilet_tissue', 'soap_dispenser', 'shower_curtain']
bedroom = ['four-poster', 'studio_couch', 'home_theater', 'pillow', 'shoji', 'wardrobe']
patio = ['patio']
restaurant = ['restaurant']
mountain_view = ['alp']
building = ['cinema', 'castle', 'palace', 'streetcar']

# %%
def kontrol_et(item):
    if item in bathroom:
        return 'bathroom'
    elif item in bedroom:
        return 'bedroom'
    elif item in patio:
        return 'patio'
    elif item in restaurant:
        return 'restaurant'
    elif item in mountain_view:
        return 'mountain_view'
    elif item in building:
        return 'building'
    
    else:
        return False

# %%
import os
if not os.path.exists('resimler'):
    os.makedirs('resimler')

# %% [markdown]
# Model her resimden 5 tane etiket tahmini uretiyor. Bu tahminlerden birisi yukaridaki listelerden birinin icerisinde ise yeni etiketi o oluyor.

# %%
def VggPredList(image):
    image = img_to_array(image)
  # veriyi model icin boyutlandir
    image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
  # resmi Vgg icin hazirla
    image = VggPre(image)
  # tahminleri al
    yhat = VGGmodel.predict(image)
  # tahminleri etiketlere ve olasiliklara donustur
    label = VggDec(yhat)

    prediction_list = []
   
    for i in range(5):
        prediction = label[0][i][1]
        prediction_list.append(prediction)
    
    return prediction_list

# %% [markdown]
# Yeni etiket atanamadıysa resim 'others' klasorune kopyalaniyor

# %%
from shutil import copy2

def kategorilendir2(img, name):
    kategoriler = VggPredList(img)
    
    for i in range(5):
        kategori = kontrol_et(kategoriler[i])
        if kategori != False:
            break
    
    if kategori == False:
        kategori = 'others'
    
    directory = 'resimler/' + kategori + '/'
    if not os.path.exists(directory):
        os.makedirs(directory)
    copy2('Imgs/' + name, directory + name)

# %%
for counter in range(1,9103):
    try:
        name = str(counter) + '.jpg'
        img = load_img('Imgs/' + name, target_size=(224, 224))
        kategorilendir2(img, name)
    except IOError:
        print('Error')
